# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 3
n = 5

M = np.random.randint(10,size=(m, n))
print(M)

plt.plot(M)
# Out:
# [[0 6 7 7 9]
#  [2 6 7 0 1]
#  [1 0 0 9 9]]
# ...

# %%
print(M)
plt.imshow(M)

for i in range(m):
    for j in range(n):
        plt.text(j, i, str(M[i, j]), 
                 fontsize=20, 
                 horizontalalignment='center', 
                 verticalalignment='center') # the x and y coordinates are flipped in text function

plt.colorbar()
plt.show()
# Out:
# [[0 6 7 7 9]
#  [2 6 7 0 1]
#  [1 0 0 9 9]]

# %%
# to import picture from web
from imageio import imread
img = imread('https://handwiki.org/wiki/images/8/86/Einstein_tongue.jpg') # this is a 2D array
# https://handwiki.org/wiki/images/8/86/Einstein_tongue.jpg
# https://m.media-amazon.com/images/I/51qvmLEZDAL._AC_.jpg
# https://upload.wikimedia.org/wikipedia/commons/5/5a/Albert_Einstein_sticks_his_tongue_1951.jpg
img.shape

plt.imshow(img,cmap='viridis') # blue to yellow color
plt.show()
# Out:
# C:\Users\arumu\AppData\Local\Temp\ipykernel_4676\52174427.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imread('https://handwiki.org/wiki/images/8/86/Einstein_tongue.jpg') # this is a 2D array

# %%
plt.hist(img.flatten(),bins=100);

# %%
plt.imshow(img,cmap='gray')
plt.show()

# %%
plt.imshow(img,cmap='gray',vmin=150,vmax=200)
plt.xticks([10,45,117])
plt.show()

# %%
plt.imshow(img,cmap='gray',vmin=150,vmax=200)
plt.xticks([])
plt.yticks([])
plt.show()

# %%
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# Hij = 1/(i+j-1)

# %%
# Exercise: visualise hilbert matrix using seaborn (heatmap)
# H is a 10x10 matrix

import numpy as np
import seaborn as sns

H = np.zeros((10, 10))

for i in range(10):
    for j in range(10):
        H[i,j]=1/((i+1)+(j+1)-1)

sns.heatmap(H,vmax = 0.4)
plt.show()

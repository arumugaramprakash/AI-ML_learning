# %%
# help! to get help for a function or method, use the built-in help function in vs codes by typing help(sum) and pressing enter. 
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
# help! to get help for a function or method, use the built-in help function in vs codes by pressing shrtcut.
x = [1, 2, 3, 4]
sum(x,10)
# Out:
# 20

# %%
sum?
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
import numpy as np
np.linspace? # the ? is used to get help on functions and methods in the numpy library.
# Out:
# Signature:
# np.linspace(
#     start,
#     stop,
#     num=50,
#     endpoint=True,
#     retstep=False,
#     dtype=None,
#     axis=0,
#     *,
#     device=None,
# )
# Call signature:  np.linspace(*args, **kwargs)
# Type:            _ArrayFunctionDispatcher
# String form:     <function linspace at 0x0000016DA7DEB2E0>
# File:            c:\users\arumu\github\ai-ml_learning\.venv\lib\site-packages\numpy\_core\function_base.py
# Docstring:
# Return evenly spaced numbers over a specified interval.
#
# Returns `num` evenly spaced samples, calculated over the
# interval [`start`, `stop`].
#
# The endpoint of the interval can optionally be excluded.
#
# .. versionchanged:: 1.20.0
#     Values are rounded towards ``-inf`` instead of ``0`` when an
#     integer ``dtype`` is specified. The old behavior can
#     still be obtained with ``np.linspace(start, stop, num).astype(int)``
#
# Parameters
# ----------
# start : array_like
#     The starting value of the sequence.
# ...

# %%
#1. Use the Up Arrow key to move up one line of code.
#2. Press Escape and then type "j" (or "j" alone) repeatedly to jump back to the previous function definition or method call.
#3. In the top navigation bar, click "Goto Definition" which will take you to the function's declaration.
#4. You can also place your cursor on the function name and press F12 to open the definition in a new tab.
#5. Use Ctrl+Shift+Left Bracket or Ctrl+Shift+Right Bracket to go back one level in nested curly braces.   
#6. Press Ctrl+Z repeatedly to undo your last action (moving back a line).  
#7. You can also use the mouse wheel to scroll up through code, which will effectively move you backwards.

# %%
np.linspace?? # the ?? is used to get help on functions and methods in the numpy library. also it shows the actual docstring of the function.
# Out:
# Signature:
# np.linspace(
#     start,
#     stop,
#     num=50,
#     endpoint=True,
#     retstep=False,
#     dtype=None,
#     axis=0,
#     *,
#     device=None,
# )
# Call signature:  np.linspace(*args, **kwargs)
# Type:            _ArrayFunctionDispatcher
# String form:     <function linspace at 0x0000016DA7DEB2E0>
# File:            c:\users\arumu\github\ai-ml_learning\.venv\lib\site-packages\numpy\_core\function_base.py
# Source:
# @array_function_dispatch(_linspace_dispatcher)
# def linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None,
#              axis=0, *, device=None):
#     """
#     Return evenly spaced numbers over a specified interval.
#
#     Returns `num` evenly spaced samples, calculated over the
#     interval [`start`, `stop`].
#
#     The endpoint of the interval can optionally be excluded.
#
#     .. versionchanged:: 1.20.0
#         Values are rounded towards ``-inf`` instead of ``0`` when an
# ...

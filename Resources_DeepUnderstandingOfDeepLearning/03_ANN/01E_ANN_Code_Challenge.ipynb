# %% [markdown]
# 1. write a python function that builds and trains the model, and outputs the final prediction and losses
# 2. write a function that creates the data and outputs x,y. x is the same as old. y = m*x+randn/2. N=50.
# 3. in a parametric experiment vary the slope m from -2 to +2 in 21 steps. Repeat the experiment 50 times.
# 4. plot the loss and accuracy corelation of yhat,y as a function of the slope

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
# data 
N = 50
x = torch.randn(N,1)
m=-2
y=m*x+torch.randn(N,1)/2
